# %% [markdown]
# Importing Useful Stuff

# %%
import csv
import os
from functools import partial
import json

import geopandas as gpd
import matplotlib.pyplot as plt

from gerrychain import (
    Election,
    Graph,
    MarkovChain,
    Partition,
    accept,
    constraints,
    updaters,
)
from gerrychain.metrics import efficiency_gap, mean_median, polsby_popper
from gerrychain.proposals import recom
from gerrychain.updaters import cut_edges, county_splits
from gerrychain.tree import recursive_tree_part
from gerrychain.constraints import SelfConfiguringUpperBound, SelfConfiguringLowerBound
from gerrychain.partition import GeographicPartition

# %% [markdown]
# Creating a path so I don't have to keep typing it, creating my dataframe and my graph (doing a graph this way is super slow so it's in its own cell so I don't have to rerun the cell very often)

# %%
path = "./CompleteCOwithDemographics.shp"
ourjson = './CompleteCOwithDemographics.json'
df = gpd.read_file(path)

# %%
#df.head()

# %%
#graph = Graph.from_file(path)
graph = Graph.from_json(ourjson)

# %%
#graph.to_json('./CompleteCOwithDemographics.json')

# %%
graph.nodes.data()
# Out:
# NodeDataView({0: {'boundary_node': False, 'area': 17412948.84609674, 'COUNTYFP': '001', 'VTDST': '001246', 'NAME': 'Adams 246', 'xcoord': -104.43454, 'ycoord': 39.74861, 'Sum_POP201': 2179.0, 'Sum_block_': 2203, 'CD116FP': '04', 'NAMELSAD': 'Congressional District 4', 'SLDUST': '025', 'NAMELSAD_1': 'State Senate District 25', 'SLDLST': '056', 'NAMELSAD_2': 'State House District 56', 'PrecinctID': 4255601246.0, 'PrecinctNu': 246, 'AG_DEM18': 218, 'AG_REP18': 584, 'SEC_DEM18': 242, 'SEC_REP18': 544, 'TRE_DEM18': 240, 'TRE_REP18': 540, 'GOV_DEM18': 228, 'GOV_REP18': 567, 'REG_DEM18': 230, 'REG_REP18': 531, 'VTDSD': 1246, 'Count_': 130, 'Sum_POP2_1': 1993.0, 'Sum_HISPAN': 205.0, 'Sum_PCT_HI': 408.01, 'Sum_WHITE_': 1736.0, 'Sum_PCT_WH': 5180.55, 'Sum_BLACK_': 2.0, 'Sum_PCT_BL': 3.64, 'Sum_AMERIN': 16.0, 'Sum_PCT_AM': 27.68, 'Sum_ASIAN_': 4.0, 'Sum_PCT_AS': 7.98, 'Sum_HAWPAC': 6.0, 'Sum_PCT_HA': 13.52, 'Sum_OTHER_': 0.0, 'Sum_PCT_OT': 0.0, 'Sum_MULT_N': 24.0, 'Sum_PCT_MU': 58.62, 'Sum_GQ_POP': 0.0, 'Sum_GQ_COR': 0.0, 'Sum_GQ_COL': 0.0, 'Sum_GQ_MIL': 0.0, 'Sum_ORIG_F': 595984}, 1: {'boundary_node': False, 'area': 411274595.28163403, 'COUNTYFP': '001', 'VTDST': '001247', 'NAME': 'Adams 247', 'xcoord': -104.32722, 'ycoord': 39.90889, 'Sum_POP201': 1609.0, 'Sum_block_': 1665, 'CD116FP': '04', 'NAMELSAD': 'Congressional District 4', 'SLDUST': '025', 'NAMELSAD_1': 'State Senate District 25', 'SLDLST': '056', 'NAMELSAD_2': 'State House District 56', 'PrecinctID': 4255601247.0, 'PrecinctNu': 247, 'AG_DEM18': 153, 'AG_REP18': 577, 'SEC_DEM18': 170, 'SEC_REP18': 556, 'TRE_DEM18': 164, 'TRE_REP18': 559, 'GOV_DEM18': 162, 'GOV_REP18': 556, 'REG_DEM18': 164, 'REG_REP18': 525, 'VTDSD': 1247, 'Count_': 154, 'Sum_POP2_1': 1138.0, 'Sum_HISPAN': 135.0, 'Sum_PCT_HI': 663.03, 'Sum_WHITE_': 966.0, 'Sum_PCT_WH': 5626.26, 'Sum_BLACK_': 3.0, 'Sum_PCT_BL': 10.89, 'Sum_AMERIN': 3.0, 'Sum_PCT_AM': 15.2, 'Sum_ASIAN_': 15.0, 'Sum_PCT_AS': 87.34, 'Sum_HAWPAC': 0.0, 'Sum_PCT_HA': 0.0, 'Sum_OTHER_': 0.0, 'Sum_PCT_OT': 0.0, 'Sum_MULT_N': 16.0, 'Sum_PCT_MU': 197.25, 'Sum_GQ_POP': 0.0, 'Sum_GQ_COR': 0.0, 'Sum_GQ_COL': 0.0, 'Sum_GQ_MIL': 0.0, 'Sum_ORIG_F': 706812}, 2: {'boundary_node': False, 'area': 108651746.73214383, 'COUNTYFP': '001', 'VTDST': '001248', 'NAME': 'Adams 248', 'xcoord': -104.29268, 'ycoord': 39.79678, 'Sum_POP201': 2015.0, 'Sum_block_': 2170, 'CD116FP': '04', 'NAMELSAD': 'Congressional District 4', 'SLDUST': '025', 'NAMELSAD_1': 'State Senate District 25', 'SLDLST': '056', 'NAMELSAD_2': 'State House District 56', 'PrecinctID': 4255601248.0, 'PrecinctNu': 248, 'AG_DEM18': 138, 'AG_REP18': 517, 'SEC_DEM18': 141, 'SEC_REP18': 505, 'TRE_DEM18': 152, 'TRE_REP18': 497, 'GOV_DEM18': 153, 'GOV_REP18': 507, 'REG_DEM18': 138, 'REG_REP18': 478, 'VTDSD': 1248, 'Count_': 47, 'Sum_POP2_1': 1307.0, 'Sum_HISPAN': 151.0, 'Sum_PCT_HI': 380.92, 'Sum_WHITE_': 1108.0, 'Sum_PCT_WH': 2452.75, 'Sum_BLACK_': 19.0, 'Sum_PCT_BL': 24.14, 'Sum_AMERIN': 6.0, 'Sum_PCT_AM': 7.94, 'Sum_ASIAN_': 7.0, 'Sum_PCT_AS': 12.92, 'Sum_HAWPAC': 0.0, 'Sum_PCT_HA': 0.0, 'Sum_OTHER_': 0.0, 'Sum_PCT_OT': 0.0, 'Sum_MULT_N': 16.0, 'Sum_PCT_MU': 21.3, 'Sum_GQ_POP': 0.0, 'Sum_GQ_COR': 0.0, 'Sum_GQ_COL': 0.0, 'Sum_GQ_MIL': 0.0, 'Sum_ORIG_F': 217505}, 3: {'boundary_node': False, 'area': 144462967.15895918, 'COUNTYFP': '001', 'VTDST': '001245', 'NAME': 'Adams 245', 'xcoord': -104.4535, 'ycoord': 39.8541, 'Sum_POP201': 1273.0, 'Sum_block_': 1409, 'CD116FP': '04', 'NAMELSAD': 'Congressional District 4', 'SLDUST': '025', 'NAMELSAD_1': 'State Senate District 25', 'SLDLST': '030', 'NAMELSAD_2': 'State House District 30', 'PrecinctID': 4253001245.0, 'PrecinctNu': 245, 'AG_DEM18': 54, 'AG_REP18': 225, 'SEC_DEM18': 66, 'SEC_REP18': 212, 'TRE_DEM18': 58, 'TRE_REP18': 216, 'GOV_DEM18': 59, 'GOV_REP18': 214, 'REG_DEM18': 58, 'REG_REP18': 210, 'VTDSD': 1245, 'Count_': 37, 'Sum_POP2_1': 575.0, 'Sum_HISPAN': 101.0, 'Sum_PCT_HI': 300.52, 'Sum_WHITE_': 450.0, 'Sum_PCT_WH': 2325.9, 'Sum_BLACK_': 1.0, 'Sum_PCT_BL': 2.38,  ...

# %%
graph.edges.data()
# Out:
# EdgeDataView([(0, 10, {'shared_perim': 5943.242217351542, 'id': 0}), (0, 11, {'shared_perim': 1602.6192996852224, 'id': 0}), (0, 3, {'shared_perim': 9590.386727368616, 'id': 0}), (0, 1, {'shared_perim': 5188.666861528875, 'id': 0}), (1, 10, {'shared_perim': 483.71931028025017, 'id': 1}), (1, 12, {'shared_perim': 1589.1053083051595, 'id': 1}), (1, 5, {'shared_perim': 1644.5503983703463, 'id': 1}), (1, 2, {'shared_perim': 20942.90284647503, 'id': 1}), (1, 3, {'shared_perim': 27351.179575195605, 'id': 1}), (1, 4, {'shared_perim': 22617.159611669496, 'id': 1}), (1, 1449, {'shared_perim': 4995.6684006989735, 'id': 1}), (1, 2902, {'shared_perim': 6413.087525661889, 'id': 1}), (1, 2862, {'shared_perim': 17642.87254930946, 'id': 1}), (2, 5, {'shared_perim': 11456.707892096743, 'id': 2}), (2, 4, {'shared_perim': 9712.905632993086, 'id': 2}), (3, 11, {'shared_perim': 3127.1490576995484, 'id': 3}), (3, 2669, {'shared_perim': 21112.70263763457, 'id': 3}), (3, 1448, {'shared_perim': 4807.339389504535, 'id': 3}), (4, 13, {'shared_perim': 11284.485309436015, 'id': 4}), (4, 14, {'shared_perim': 33404.6297109396, 'id': 4}), (4, 5, {'shared_perim': 1610.2259295402318, 'id': 4}), (4, 2750, {'shared_perim': 29025.898301153615, 'id': 4}), (4, 270, {'shared_perim': 12947.416012487476, 'id': 4}), (4, 277, {'shared_perim': 2589.892237527438, 'id': 4}), (4, 2862, {'shared_perim': 4918.622833100738, 'id': 4}), (4, 278, {'shared_perim': 4746.05821012557, 'id': 4}), (4, 267, {'shared_perim': 17703.319274025238, 'id': 4}), (5, 12, {'shared_perim': 6415.500519774591, 'id': 5}), (5, 13, {'shared_perim': 4789.207633332893, 'id': 5}), (6, 1671, {'shared_perim': 559.5090878361225, 'id': 6}), (6, 7, {'shared_perim': 4457.39293235993, 'id': 6}), (6, 1634, {'shared_perim': 1903.236588889292, 'id': 6}), (6, 1632, {'shared_perim': 1661.4558729213902, 'id': 6}), (6, 2678, {'shared_perim': 2199.034489903866, 'id': 6}), (6, 8, {'shared_perim': 3148.4967854723704, 'id': 6}), (6, 1663, {'shared_perim': 2359.522040183195, 'id': 6}), (7, 1671, {'shared_perim': 5692.282046121419, 'id': 7}), (7, 2679, {'shared_perim': 2548.8694090402028, 'id': 7}), (7, 2676, {'shared_perim': 1268.2279171761354, 'id': 7}), (7, 1632, {'shared_perim': 1630.7191634659384, 'id': 7}), (8, 2680, {'shared_perim': 4017.723003008848, 'id': 8}), (8, 1634, {'shared_perim': 3049.2848133456023, 'id': 8}), (8, 10, {'shared_perim': 811.4430133000664, 'id': 8}), (8, 11, {'shared_perim': 5576.194373575093, 'id': 8}), (8, 9, {'shared_perim': 4104.520790272899, 'id': 8}), (8, 1663, {'shared_perim': 7409.658290876496, 'id': 8}), (8, 2677, {'shared_perim': 1626.7687939723462, 'id': 8}), (9, 11, {'shared_perim': 4097.3619318093, 'id': 9}), (10, 196, {'shared_perim': 4810.339841094102, 'id': 10}), (10, 202, {'shared_perim': 11425.263339939203, 'id': 10}), (10, 198, {'shared_perim': 1476.282054240488, 'id': 10}), (10, 2680, {'shared_perim': 8815.659595093472, 'id': 10}), (10, 12, {'shared_perim': 20980.036205421977, 'id': 10}), (10, 11, {'shared_perim': 24140.408030199396, 'id': 10}), (11, 2677, {'shared_perim': 3752.1334670632205, 'id': 11}), (11, 2668, {'shared_perim': 901.8873331247103, 'id': 11}), (11, 2669, {'shared_perim': 8420.732451696214, 'id': 11}), (12, 205, {'shared_perim': 6933.016300045807, 'id': 12}), (12, 202, {'shared_perim': 2832.645096807447, 'id': 12}), (12, 13, {'shared_perim': 19317.017215952954, 'id': 12}), (13, 205, {'shared_perim': 9517.447150139898, 'id': 13}), (13, 14, {'shared_perim': 26014.407456825385, 'id': 13}), (14, 239, {'shared_perim': 625.6971359661146, 'id': 14}), (14, 205, {'shared_perim': 39512.91197608142, 'id': 14}), (14, 2750, {'shared_perim': 19269.778924983602, 'id': 14}), (15, 17, {'shared_perim': 20424.426082795326, 'id': 15}), (15, 18, {'shared_perim': 34459.237800461255, 'id': 15}), (15, 223, {'shared_perim': 72093.638134655, 'id': 15}), (15, 16, {'shared_perim': 52038.84749951107, 'id': 15}), (15, 26, {'shared_perim': 17778.38128233116, 'id': 15}), (15, 316, {'shared ...

# %%
#Graph = graph.from_geodataframe(df)

# %%
###So from the geodataframe gave me way less data than from the file, so that's good to know

# %%
#Graph.nodes.data()

# %%
#Graph.edges.data()

# %% [markdown]
# Creating a file to save all the data from so stuff doesn't get cluttered.

# %%
newdir = "./PACongressReplicaSimpleOutput1/"
os.makedirs(os.path.dirname(newdir + "init.txt"), exist_ok=True)
with open(newdir + "init.txt", "w") as f:
    f.write("Created Folder")

# %% [markdown]
# Giving it information about the shapefile columns and elections and what not

# %%
unique_label = "VTDSD"
census_pop = "Sum_POP2_1"
#pop_est = "Sum_block_" this is awful for whatever reason and needs updating
congress = "CD116FP"
senate = "SLDUST"
house = "SLDLST"
county_field_name = "COUNTYFP"

num_elections = 5
election_names = [
    "AG18",
    "SEC18",
    "TRE18",
    "GOV18",
    "REG18",
]
election_columns = [
    ["AG_DEM18", "AG_REP18"],
    ["SEC_DEM18", "SEC_REP18"],
    ["TRE_DEM18", "TRE_REP18"],
    ["GOV_DEM18", "GOV_REP18"],
    ["REG_DEM18", "REG_REP18"],
]

num_districts = 7

# %%
############ Why this isn't an updater I'm not entirely sure...  UPDATE: It is now as far as I'm concerned
def num_splits(partition, df=df, level = county_field_name):
    df["current"] = df[unique_label].map(dict(partition.assignment))
    splits = sum(df.groupby(level)["current"].nunique() > 1)
    return splits
splits_constraint = SelfConfiguringUpperBound(num_splits)

# %%
#num_splits(enacted_partition, df, county_field_name)
#dictionary = polsby_popper(enacted_partition)
#print(dictionary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a0b5fd27ac53> in <module>
# ----> 1 num_splits(enacted_partition, df, county_field_name)
#       2 dictionary = polsby_popper(enacted_partition)
#       3 print(dictionary)
#
# NameError: name 'enacted_partition' is not defined

# %%
total = 1/dictionary['04'] + 1/dictionary['05'] + 1/dictionary['03'] + 1/dictionary['02'] + 1/dictionary['01'] + 1/dictionary['06'] + 1/dictionary['07']
print(total/7)
# Out:
# 5.4621785500792095

# %%
def polsby_popper_average(partition):
    total = 0
    size = 0
    dictionary = polsby_popper(partition)
    for part in partition.parts:
        item = dictionary[part]
        inverse = 1 / item
        total += inverse
        size += 1
    return total / size

# %%
polsby_popper_average(enacted_partition)
# Out:
# 5.4621785500792095

# %%
polsby_popper_constraint = SelfConfiguringUpperBound(polsby_popper_average)

# %%
myupdaters = {
    "population": updaters.Tally(census_pop, alias="population"),
    "cut_edges": cut_edges,
    "county_splits": num_splits,
    "polsby_popper": polsby_popper,
    "polsby_popper_average": polsby_popper_average
}

elections = [
    Election(
        election_names[i],
        {"Democratic": election_columns[i][0], "Republican": election_columns[i][1]},
    )
    for i in range(num_elections)
]

election_updaters = {election.name: election for election in elections}

myupdaters.update(election_updaters)

# %%
enacted_partition = GeographicPartition(graph = graph, assignment = congress, updaters = myupdaters)
ideal_population = sum(enacted_partition['population'].values()) / len(enacted_partition)
print(ideal_population)

### This is how you create a random starting seed
#cddict = recursive_tree_part(graph, range(num_districts), ideal_population, census_pop, .001, 1)

#df['random'] = df.index.map(cddict)

#df.plot(column = 'random', cmap = 'jet')
#plt.savefig(newdir + 'random.png')
#plt.close()

#with open(newdir + 'random.json', 'w') as jf1:
#    json.dump(cddict, jf1)
    
#random_partition = Partition(graph, cddict, updaters)

chosen_partition = enacted_partition
# Out:
# 718456.5714285715

# %%
for district, pop in chosen_partition["population"].items():
    print("District {}: {}".format(district, pop))
# Out:
# District 04: 718435.0
# District 05: 718488.0
# District 03: 718719.0
# District 01: 717094.0
# District 06: 718460.0
# District 02: 718377.0
# District 07: 719623.0

# %%
#print(df.plot(column = 'random', cmap = 'jet'))
print(df.plot(column = congress, cmap = 'jet'))
# Out:
# AxesSubplot(0.125,0.170331;0.775x0.664339)

# %%
#cut_edges_compactness_bound = constraints.UpperBound(
#    lambda p: len(p["cut_edges"]), len(enacted_partition["cut_edges"])
#)

# %%
proposal = partial(
    recom, pop_col=census_pop, pop_target=ideal_population, epsilon=0.02, node_repeats=2
)

# %%
#polsby_popper(enacted_partition)
#enacted_partition.keys()

# %%
#polsby_constraint = SelfConfiguringLowerBound(polsby_popper)

# %%
#splits_constraint(enacted_partition)

# %%
chain = MarkovChain(
    proposal=proposal,
    constraints=[
        constraints.within_percent_of_ideal_population(enacted_partition, 0.01),
        polsby_popper_constraint, 
        #splits_constraint, 
        constraints.contiguous # single_flip_contiguous#no_more_discontiguous
    ],
    accept=accept.always_accept,
    initial_state=chosen_partition,
    total_steps=1000,
)

# %%
#to access the information/individual states:
#for state in chain:
#    do_something(current_partition)

# %%
with open(newdir + "Start_Values.txt", "w") as f:
    f.write("Values for Starting Plan: Random Plan\n \n ")
    f.write("Initial Cut: " + str(len(chosen_partition["cut_edges"])))
    f.write("\n")
    f.write("\n")
    f.write("Initial County Splits: " + str(num_splits(chosen_partition)))
    f.write("\n")
    f.write("\n")
    f.write("Initial Polsby-Popper: " + str(polsby_popper(chosen_partition)))
    f.write("\n")
    f.write("\n")
    f.write("Initial Polsby-Popper Inverse Average: " + str(polsby_popper_average(chosen_partition)))
    f.write("\n")
    f.write("\n")

    for elect in range(num_elections):
        f.write(
            election_names[elect]
            + "District Percentages"
            + str(
                sorted(chosen_partition[election_names[elect]].percents("Democratic"))
            )
        )
        f.write("\n")
        f.write("\n")

        f.write(
            election_names[elect]
            + "Mean-Median :"
            + str(mean_median(chosen_partition[election_names[elect]]))
        )

        f.write("\n")
        f.write("\n")

        f.write(
            election_names[elect]
            + "Efficiency Gap :"
            + str(efficiency_gap(chosen_partition[election_names[elect]]))
        )

        f.write("\n")
        f.write("\n")

        f.write(
            election_names[elect]
            + "How Many Seats :"
            + str(chosen_partition[election_names[elect]].wins("Democratic"))
        )

        f.write("\n")
        f.write("\n")

# %%
pop_vec = [] #population
cut_vec = [] #cut edges
votes = [[], [], [], [], []] #one list for each election
mms = [] #mean median list of lists eventually
egs = [] #efficiency gap list of lists eventually
hmss = [] #democratic seat share
pp = [] #polsby popper
pp_avg = [] #inverse average polsby popper

splits = []

t = 0
for part in chain:
    splits.append(part['county_splits'])
    pp.append(sorted(list(part['polsby_popper'].values())))
    pp_avg.append(part['polsby_popper_average'])

    pop_vec.append(sorted(list(part["population"].values())))
    cut_vec.append(len(part["cut_edges"]))
    mms.append([])
    egs.append([])
    hmss.append([])

    for elect in range(num_elections):
        votes[elect].append(sorted(part[election_names[elect]].percents("Democratic")))
        mms[-1].append(mean_median(part[election_names[elect]]))
        egs[-1].append(efficiency_gap(part[election_names[elect]]))
        hmss[-1].append(part[election_names[elect]].wins("Democratic"))

    t += 1
    if t % 100 == 0:
        print(t)
        with open(newdir + "mms" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows(mms)
            
        with open(newdir + "pp" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows([pp])
        
        with open(newdir + "pp_avg" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows([pp_avg])

        with open(newdir + "egs" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows(egs)

        with open(newdir + "hmss" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows(hmss)

        with open(newdir + "pop" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows(pop_vec)

        with open(newdir + "cuts" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows([cut_vec])

        with open(newdir + "splits" + str(t) + ".csv", "w") as tf1:
            writer = csv.writer(tf1, lineterminator="\n")
            writer.writerows([splits])

        with open(newdir + "assignment" + str(t) + ".json", "w") as jf1:
            json.dump(dict(part.assignment), jf1)

        for elect in range(num_elections):
            with open(
                newdir + election_names[elect] + "_" + str(t) + ".csv", "w"
            ) as tf1:
                writer = csv.writer(tf1, lineterminator="\n")
                writer.writerows(votes[elect])

        df["plot" + str(t)] = df.index.map(dict(part.assignment))
        df.plot(column="plot" + str(t), cmap="jet")
        plt.savefig(newdir + "plot" + str(t) + ".png")
        plt.close()

        votes = [[], [], [], [], []]
        mms = []
        egs = []
        hmss = []
        pop_vec = []
        cut_vec = []
        splits = []
        pp = []
        pp_avg = []
# Out:
# 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5c131af02e36> in <module>
#      11
#      12 t = 0
# ---> 13 for part in chain:
#      14     splits.append(part['county_splits'])
#      15     pp.append(sorted(list(part['polsby_popper'].values())))
#
# ~/.local/lib/python3.7/site-packages/gerrychain/chain.py in __next__(self)
#      65
#      66         while self.counter < self.total_steps:
# ---> 67             proposed_next_state = self.proposal(self.state)
#      68             # Erase the parent of the parent, to avoid memory leak
#      69             self.state.parent = None
#
# ~/.local/lib/python3.7/site-packages/gerrychain/proposals/tree_proposals.py in recom(partition, pop_col, pop_target, epsilon, node_repeats)
#      44         pop_target=pop_target,
#      45         epsilon=epsilon,
# ---> 46         node_repeats=node_repeats,
#      47     )
#      48
#
# ~/.local/lib/python3.7/site-packages/gerrychain/tree.py in recursive_tree_part(graph, parts, pop_target, pop_col, epsilon, node_repeats)
#     130             pop_target=pop_target,
#     131             epsilon=epsilon,
# --> 132             node_repeats=node_repeats,
#     133         )
#     134
#
# ~/.local/lib/python3.7/site-packages/gerrychain/tree.py in bipartition_tree(graph, pop_col, pop_target, epsilon, node_repeats, spanning_tree, choice)
#      97     while balanced_subtree is None:
#      98         if restarts == node_repeats:
# ---> 99             spanning_tree = random_spanning_tree(graph)
#     100             restarts = 0
#     101         h = PopulatedGraph(spanning_tree.copy(), populations, pop_target, epsilon)
#
# ~/.local/lib/python3.7/site-packages/gerrychain/tree.py in random_spanning_tree(graph)
#      11 def random_spanning_tree(graph):
#      12     for edge in graph.edges:
# ---> 13         graph.edges[edge]["weight"] = random.random()
#      14
#      15     spanning_tree = tree.maximum_spanning_tree(
#
# ~/.local/lib/python3.7/site-packages/networkx/classes/reportviews.py in __getitem__(self, e)
#     928     def __getitem__(self, e):
#     929         u, v = e
# --> 930         return self._adjdict[u][v]
#     931
#     932     # EdgeDataView methods
#
# KeyboardInterrupt:
